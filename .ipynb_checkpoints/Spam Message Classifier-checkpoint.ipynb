# %% [markdown]
# ### Importing Libraries for data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/spam.tsv", sep='\t')

# %%
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (5572, 4)

# %% [markdown]
# ### Dataset Balancing

# %%
ham = df[df['label'] == 'ham' ]
ham.shape
# Out:
# (4825, 4)

# %%
spam = df[df['label'] == 'spam']

# %%
spam.shape
# Out:
# (747, 4)

# %%
ham = ham.sample(spam.shape[0])

# %%
ham.shape
# Out:
# (747, 4)

# %%
data = pd.concat([ham, spam], axis=0, ignore_index=True)
data.shape
# Out:
# (1494, 4)

# %%
data.sample(10)
# Out:
#      label                                            message  length  punct
# 1068  spam  Moby Pub Quiz.Win a £100 High Street prize if ...     160      4
# 1048  spam  Sunshine Hols. To claim ur med holiday send a ...     161      7
# 1300  spam  U have a secret admirer who is looking 2 make ...     132      3
# 58     ham  I enjoy watching and playing football and bask...      81      3
# 203    ham  Great. P diddy is my neighbor and comes for to...      68      1
# 449    ham  sir, you will receive the account no another 1...      75      3
# 324    ham  Lol I have to take it. member how I said my au...     153      6
# 1390  spam  Urgent -call 09066649731from Landline. Your co...     146      6
# 711    ham                   How much did ur hdd casing cost.      32      1
# 812   spam  Loan for any purpose £500 - £75,000. Homeowner...     162      9

# %% [markdown]
# ### Visualization of the dataset

# %%
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = (10, 4)
plt.style.use('ggplot')

# %%
ham.columns
# Out:
# Index(['label', 'message', 'length', 'punct'], dtype='object')

# %%
plt.hist(ham['length'], bins=100, alpha=0.9, label='HAM')
plt.hist(spam['length'], bins=100, alpha=0.9, label='SPAM')
plt.title("The length comparison of spam and ham messages")
plt.legend()
plt.show()

# %%
plt.hist(ham['punct'], bins=100, alpha=0.9, label='HAM')
plt.hist(spam['punct'], bins=100, alpha=0.9, label='SPAM')
plt.title("The punctuation comparison of spam and ham messages")
plt.legend()
plt.show()

# %% [markdown]
# ### Training and testing of the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
